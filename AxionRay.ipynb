# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx")

# %%
import pandas as pd
file_path = '/content/Analyst Assignment_Task_DataSheet..xlsx' # Load the Excel file
excel_data = pd.ExcelFile(file_path)

excel_data.sheet_names
# Out:
# ['Task 1',
#  'Task_1 Taxonomy',
#  'Task 2',
#  'Task_2 Taxonomy',
#  'Task 3_Raw Data',
#  'Task 3_Guidelines',
#  'Data Validation_ Template (Task']

# %%
df.describe()
# Out:
#        Failure Condition 2  Failure Component 2
# count                  0.0                  0.0
# mean                   NaN                  NaN
# std                    NaN                  NaN
# min                    NaN                  NaN
# 25%                    NaN                  NaN
# 50%                    NaN                  NaN
# 75%                    NaN                  NaN
# max                    NaN                  NaN

# %%
# Task_1 Taxonomy sheets
task_1_data = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task 1')
task_1_taxonomy = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task_1 Taxonomy')

# Display 10 rows
task_1_data.head(10), task_1_taxonomy.head(10)
# Out:
# (              _Id Returned      Product Name Product Segment  Rating  \
#  0  R1060RBTFRFE48      Yes           Swing 1    Baby Product  1 Star
#  1  R13DJ77EZFAIWI      Yes  Seat & Bouncer 1    Baby Product  1 Star
#  2  R15NYSUD9N39B7       No        Car Seat 1    Baby Product  4 Star
#  3  R15UXWMELB3VVP      Yes           Swing 1    Baby Product  1 Star
#  4  R168A29OOS1W0B      Yes        Car Seat 1    Baby Product  2 Star
#  5  R1A4KLB4ZCZSTT      Yes   Travel System 1    Baby Product  1 Star
#  6  R1CELHXQRKVJF2      Yes   Travel System 1    Baby Product  1 Star
#  7  R1DIVNPAIGHPHF      Yes        Car Seat 1    Baby Product  2 Star
#  8  R20LGOTJ0NTTGD      Yes        Stroller 1    Baby Product  1 Star
#  9  R2D0R8NU0JRPRV      Yes           Swing 1    Baby Product  2 Star
#
#                                                Review  \
#  0  I purchased one of these swings for my last ch...
#  1  I ho ly feel bad I asked for his and family pa...
#  2  This Brand Car Seat 12 swivel convertible car ...
#  3  seat bucket is angled too deep causing baby's ...
#  4  Installing is pretty easy, the locking mechani...
#  5  Received this as a baby shower gift this year....
#  6  I bought this stroller hoping it would serve a...
#  7  Displeased with this car seat.\n- slides/moves...
#  8  Over the stroller is ok.... The CHILD'S TRAY w...
#  9  The swing is nice but it’s way too big for a n...
#
#                                                 Title  \
#  0                                            All bad
#  1                                           NOT SAFE
#  2             Will be buying this for future babies!
#  3              The seat bucket is angled incorrectly
#  4  Does not rotate easily if car has bolstered re...
#  5                     Dangerous! Brakes did not work
#  6  Very uncomfortable manuevre and Unaligned move...
#  7                                        Greco swing
#  8                                    Product support
#  9                             Too wide for a newborn
#
#                    Sentiment 1            Sentiment 2 Symtom Condition 1  \
#  0             Unsatisfactory   Poor Design & Quality         Discomfort
#  1  Satisfactory & Recommended         Unsatisfactory             Uneven
#  2                         NaN                    NaN                NaN
#  3                         NaN                    NaN                NaN
#  4                         NaN                    NaN                NaN
#  5                         NaN                    NaN                NaN
#  6                         NaN                    NaN                NaN
#  7                         NaN                    NaN                NaN
#  8                         NaN                    NaN                NaN
#  9                         NaN                    NaN                NaN
#
#    Symptom Component 1      Symtom Condition 2 Symptom Component 2  \
#  0                Seat             Audio Issue             Speaker
#  1          Swing Base  Incorrect Installation              Swing
#  2                 NaN                     NaN                 NaN
#  3                 NaN                     NaN                 NaN
#  4                 NaN                     NaN                 NaN
#  5                 NaN                     NaN                 NaN
#  6                 NaN                     NaN                 NaN
#  7                 NaN                     NaN                 NaN
#  8                 NaN                     NaN                 NaN
#  9                 NaN                     NaN                 NaN
#
#    Symtom Condition 3 Symptom Component 3 Failure Condition 1  \
#  0              Noise              Swing          Inoperative
#  1                NaN                 NaN                Bent
#  2                NaN                 NaN                 NaN
#  3                NaN                 NaN                 NaN
#  4                NaN                 NaN                 NaN
#  5                NaN                 NaN                 NaN
#  6                NaN                 NaN                 NaN
#  7                NaN                 NaN                 NaN
#  8                NaN                 NaN                 NaN
#  9                NaN                 NaN                 NaN
#
#    Failure Component 1  Failure Condition 2  Failure Component 2
#  0      Mobile Toy Kit                  NaN                  NaN
#  1           Swing Bar                  NaN                  NaN
#  2                 NaN                  NaN                  NaN
#  3                 NaN                  NaN                  NaN
#  4                 NaN                  NaN                  NaN
#  5                 NaN                  NaN                  NaN
#  6                 NaN                  NaN                  NaN
#  7                 NaN                  NaN                  NaN
#  8                 NaN                  NaN                  NaN
#  9                 NaN                  NaN                  NaN  ,
#                            Sentiment             Symptom Condition  \
#  0              Unsatisfactory (Neg)                    Discomfort
#  1  Satisfactory & Recommended (Pos)                        Uneven
#  2       Poor Design & Quality (Neg)  Cleaning Instruction Inquiry
#  3            Difficult to Use (Neg)           Uncomfortable Angle
#  4         Not Worth The Money (Neg)                   Not Secured
#  5               User Friendly (Pos)                   Inoperative
#  6               Good Features (Pos)             Abnormal Movement
#  7             Price Effective (Pos)                         Noise
#  8                Bad Features (Neg)         Difficult to Assemble
#  9            Limited Features (Neg)                     Too Large
#
#    Symptom Component Failure Condition Failure Component
#  0              Seat       Inoperative    Mobile Toy Kit
#  1        Swing Base              Bent         Swing Bar
#  2        Seat Cover             Loose              Seat
#  3           Harness        Misaligned       Seat Buckle
#  4             Brake            Rubbed             Brake
#  5             Wheel         Too Small              Belt
#  6              Tray            Broken              Tray
#  7             Swing           Missing    Vibration Unit
#  8             Strap              Torn          Seat Pad
#  9               Pad            Jammed         Seat Belt  )

# %%
# Task_2 Taxonomy sheets
task_2_data = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task 2')
task_2_taxonomy = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task_2 Taxonomy')

# Display 10 rows
task_2_data.head(10), task_2_taxonomy.head(10)
# Out:
# (  Event id Opened date                                    CAUSAL_VERBATIM  \
#  0  D-14465  2021-01-19  SCANNED VEHICLE AND FOUND DTCS   SET IN THE AM...
#  1  D-14571  2021-02-08  VERIFIED CONCERN. CHECKED AND FOUND DOCUMENT #...
#  2  D-14580  2020-12-07               Unable to duplicate customer concern
#  3  D-14615  2020-09-11  INTERNAL RADIO MALFUNCTION, FAULTY READER, AND...
#  4  D-14619  2019-12-23  scanned for DTCs using   no DTCs while trying ...
#
#                                   CORRECTION_VERBATIM  \
#  0  REPLACED AND PROGRAMMED RADIO RECEIVER PROGRAM...
#  1  VERIFIED CONCERN. CHECKED AND FOUND DOCUMENT #...
#  2  At this time radio powers up and has display a...
#  3  I STARTED THE CAR WITH THE OWNER, AND VERIFIED...
#  4  scanned for DTC's using   (no DTC's), while tr...
#
#                                     CUSTOMER_VERBATIM  \
#  0  CUSTOMER STATES THAT RADIO POWER WILL BE ON AN...
#  1  CUSTOMER STATES WHEN SHUTTING OFF CAR,RADIO,HE...
#  2  customer concern radio blacks out and has no a...
#  3  CHECK & ADVISE - CUSTOMER STATES THAT THE NAVI...
#  4  Advise on touch screen function inop Tech Caus...
#
#                   BUILD_DATE BUILD_PLANT_DESC  \
#  0  2019-08-01T00:00:00.000Z       Fort Wayne
#  1  2019-08-06T00:00:00.000Z            Silao
#  2  2019-08-07T00:00:00.000Z            Flint
#  3  2019-08-07T00:00:00.000Z            Silao
#  4  2019-08-08T00:00:00.000Z            Silao
#
#                                  CAUSAL_CD_DESC  \
#  0                     Module/Component-Shorted
#  1  Module/Component-No/Incorrect Communication
#  2  Module/Component-No/Incorrect Communication
#  3  Module/Component-No/Incorrect Communication
#  4       Module/Component-Registers Incorrectly
#
#                                     COMPLAINT_CD_DESC  \
#  0  Features/Controls/Displays - Gauges/Warning Li...
#  1      Audio/Entertainment/Navigation - Other issues
#  2             Audio/Entertainment/Navigation - Audio
#  3        Audio/Entertainment/Navigation - Navigation
#  4     Audio/Entertainment/Navigation - Communication
#
#                  IN_USE_DATE  ...    Failure Condition 2  \
#  0  2019-12-09T00:00:00.000Z  ...  Loss of Communication
#  1  2020-02-24T00:00:00.000Z  ...      Not Shutting Down
#  2  2020-07-31T00:00:00.000Z  ...                    NaN
#  3  2019-10-01T00:00:00.000Z  ...                    NaN
#  4  2020-05-30T00:00:00.000Z  ...                    NaN
#
#                Failure Component 2 Failure Condition 3 Failure Component 3  \
#  0  Telematic Communication Module      Internal Fault      Radio Receiver
#  1                            HVAC                 NaN                 NaN
#  2                             NaN                 NaN                 NaN
#  3                             NaN                 NaN                 NaN
#  4                             NaN                 NaN                 NaN
#
#    Fix Condition 1 Fix Component 1 Fix Condition 2 Fix Component 2  \
#  0        Replaced  Radio Receiver      Programmed             USB
#  1        Replaced           Radio      Programmed        SPS Port
#  2             NaN             NaN             NaN             NaN
#  3             NaN             NaN             NaN             NaN
#  4             NaN             NaN             NaN             NaN
#
#    Fix Condition 3 Fix Component 3
#  0             NaN             NaN
#  1      Programmed             USB
#  2             NaN             NaN
#  3             NaN             NaN
#  4             NaN             NaN
#
#  [5 rows x 26 columns],
#  Empty DataFrame
#  Columns: [Trigger, Failure Condition, Failure Component, Fix Condition, Fix Component]
#  Index: [])

# %%
# Task 3_Raw Data and Data Validation Template sheets
task_3_raw_data = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task 3_Raw Data')
data_validation_template = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Data Validation_ Template (Task')

# Display 10 rows
task_3_raw_data.head(), data_validation_template.head()
# Out:
# (       ID Complaint_number Shipment Date created_date current_phase  \
#  0  103339     K-0002103339    2020-08-13   2024-03-02        Closed
#  1  103470     K-0002103470    2020-08-13   2024-03-02        Closed
#  2  103932     K-0002103932    2020-08-13   2024-03-03        Closed
#  3  104129     K-0002104129    2020-08-13   2024-03-03        Closed
#  4  104186     K-0002104186    2020-08-13   2024-03-03        Closed
#
#    aware_date    Plant          part_description           part_action  \
#  0 2023-12-27  Plant 1  PENDANT,STANDARD W/O ENT  REPLACED DO NOT BILL
#  1 2023-12-27  Plant 1          GCI POD 8 SERIES              REPLACED
#  2 2024-01-02  Plant 1       CBL ASSY,USB BB/GUI  REPLACED DO NOT BILL
#  3 2024-01-02  Plant 1          GCI POD 8 SERIES              REPLACED
#  4 2023-12-28  Plant 1             WELDMENT,BACK              REPLACED
#
#                                     incident_summary2  \
#  0  What: Customer alleged that the pendant cable ...
#  1  What: The customer alleged that the graphical ...
#  2  What: The customer alleged that the right side...
#  3  What: The customer alleged no more steering._x...
#  4  What: The customer alleged that the head secti...
#
#                                           as_reported  \
#  0  BED FRAMES & INTEGRATED SURFACES-PHYSICAL DAMA...
#  1  BED FRAMES & INTEGRATED SURFACES-GCI HAS NO DI...
#  2  BED FRAMES & INTEGRATED SURFACES-GCI SCREEN FL...
#  3          BED FRAMES & INTEGRATED SURFACES-NO STEER
#  4  BED FRAMES & INTEGRATED SURFACES-PHYSICAL DAMA...
#
#                             investigation_conclusion2  \
#  0  Troubleshooting/Assessment: Upon inspection, t...
#  1  Troubleshooting/Assessment: The Technical Cust...
#  2  Troubleshooting/Assessment: Upon inspection, t...
#  3  Troubleshooting/Assessment: Upon inspection, t...
#  4  Troubleshooting/Assessment: Upon inspection, t...
#
#                            troubleshooting_assessment  \
#  0  Troubleshooting/Assessment: Upon inspection, t...
#  1  Troubleshooting/Assessment: The Technical Cust...
#  2  Troubleshooting/Assessment: Upon inspection, t...
#  3  Troubleshooting/Assessment: Upon inspection, t...
#  4  Troubleshooting/Assessment: Upon inspection, t...
#
#                                         repair_retest  \
#  0  Repair/Retest: The Field Service Technician re...
#  1  Repair/Retest: The Technical Customer Support ...
#  2  Repair/Retest: The Field Service Technician re...
#  3  Repair/Retest: The Field Service Technician re...
#  4  Repair/Retest: The Field Service Technician re...
#
#    as_determined_by_final_assessment                       module  \
#  0                    M034 F138 C013           M034-User Controls
#  1                    M014 F070 C013  M014-Display and Indicators
#  2                    M014 F070 C013  M014-Display and Indicators
#  3                    M024 F091 C013             M024-Power Drive
#  4                    M005 F133 C031            M005-Articulation
#
#                    failure_mode  \
#  0            G138-User control
#  1  G070-Display and Indicators
#  2  G070-Display and Indicators
#  3             G091-Power Drive
#  4        G133-User Error-abuse
#
#                                                 cause  \
#  0                    Y013-Electronic control failure
#  1                    Y013-Electronic control failure
#  2                    Y013-Electronic control failure
#  3  Y006-Battery failure and or installed incorrectly
#  4                               Y031-Use error:abuse
#
#     has_there_been_an_allegation_of_injury_or_death  \
#  0                                              NaN
#  1                                              NaN
#  2                                              NaN
#  3                                              NaN
#  4                                              NaN
#
#                                        diligence_log2
#  0  1. Where was the product (hospital department)...
#  1  1. Where was the product (hospital department)...
#  2  Per LCC analyst -  Replacement of the blower m...
#  3  Per LCC analyst_x000D_\nPer LCC analyst - Mult...
#  4  ~ Service/Work Order Source - Customer Request...  ,
#     Unnamed: 0            Unnamed: 1   Unnamed: 2    Unnamed: 3     Unnamed: 4  \
#  0         NaN  Column wise analysis          NaN           NaN            NaN
#  1         NaN            Field Name  Description  Total Values  Unique Values
#  2         NaN                   NaN          NaN           NaN            NaN
#  3         NaN                   NaN          NaN           NaN            NaN
#  4         NaN                   NaN          NaN           NaN            NaN
#
#    Unnamed: 5                           Unnamed: 6          Unnamed: 7  \
#  0        NaN                                  NaN                 NaN
#  1  Data type  What can be mined from this column?  Null Values if Any
#  2        NaN                                  NaN                 NaN
#  3        NaN                                  NaN                 NaN
#  4        NaN                                  NaN                 NaN
#
#                 Unnamed: 8
#  0                     NaN
#  1  Any additional comment
#  2                     NaN
#  3                     NaN
#  4                     NaN  )

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
file_path = '/content/Analyst Assignment_Task_DataSheet..xlsx'
task_1_data = pd.read_excel(file_path, sheet_name='Task 1')

# Sentiment Analysis
sentiment_counts = task_1_data['Sentiment 1'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Frequent Symptoms
symptom_counts = task_1_data['Symtom Condition 1'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=symptom_counts.index, y=symptom_counts.values, palette='coolwarm')
plt.title('Most Common Symptoms')
plt.xlabel('Symptom Condition')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-b483fe33d82a>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')
# <ipython-input-23-b483fe33d82a>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=symptom_counts.index, y=symptom_counts.values, palette='coolwarm')

# %%
print(task_1_data.columns)
# Out:
# Index(['_Id', 'Returned', 'Product Name', 'Product Segment', 'Rating',
#        'Review', 'Title', 'Sentiment 1', 'Sentiment 2', 'Symtom Condition 1',
#        'Symptom Component 1', 'Symtom Condition 2', 'Symptom Component 2',
#        'Symtom Condition 3', 'Symptom Component 3', 'Failure Condition 1',
#        'Failure Component 1', 'Failure Condition 2', 'Failure Component 2'],
#       dtype='object')

# %%
# Load data
task_2_data = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task 2')

# Failure Conditions
failure_counts = task_2_data['Failure Condition 1'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=failure_counts.index, y=failure_counts.values, palette='Blues')
plt.title('Most Frequent Failure Conditions')
plt.xlabel('Failure Condition')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Fix Components
fix_counts = task_2_data['Fix Component 1'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=fix_counts.index, y=fix_counts.values, palette='Greens')
plt.title('Most Common Fix Components')
plt.xlabel('Fix Component')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-20-4e4984c750d9>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=failure_counts.index, y=failure_counts.values, palette='Blues')
# <ipython-input-20-4e4984c750d9>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=fix_counts.index, y=fix_counts.values, palette='Greens')

# %%
# Load raw data for validation
task_3_raw_data = pd.read_excel("/content/Analyst Assignment_Task_DataSheet..xlsx", sheet_name='Task 3_Raw Data')

# Unique Values per Column
unique_values = task_3_raw_data.nunique()

# Visualize Unique Values
plt.figure(figsize=(12, 6))
sns.barplot(x=unique_values.index, y=unique_values.values, palette='magma')
plt.title('Unique Values per Column')
plt.xlabel('Columns')
plt.ylabel('Unique Values')
plt.xticks(rotation=90)
plt.show()

# Missing Data
missing_data = task_3_raw_data.isnull().sum()
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_data.index, y=missing_data.values, palette='rocket')
plt.title('Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Missing Values')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-21-2c40f23f3dbf>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=unique_values.index, y=unique_values.values, palette='magma')
# <ipython-input-21-2c40f23f3dbf>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=missing_data.index, y=missing_data.values, palette='rocket')
